# %% [markdown]
# # Price Trend Analysis – Dairy Products

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load cleaned dataset
df = pd.read_csv("../data/dairy_prices_cleaned.csv", parse_dates=['Date'])

# %%
# Set plot style
sns.set(style="whitegrid")

# %% [markdown]
# ## 1. Average price over time (All countries/products)

# %%
monthly_avg = df.groupby("Date")["Price_EUR_per_kg"].mean().reset_index()

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(data=monthly_avg, x="Date", y="Price_EUR_per_kg")
plt.title("Average Dairy Price Over Time")
plt.ylabel("EUR/kg")
plt.xlabel("Date")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Price trends by product (all countries)

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(data=df, x="Date", y="Price_EUR_per_kg", hue="Product")
plt.title("Price Trends by Product")
plt.ylabel("EUR/kg")
plt.xlabel("Date")
plt.legend(title="Product")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Country-specific trend for one product

# %%
milk_df = df[df["Product"] == "Whole Milk"]

plt.figure(figsize=(12, 5))
sns.lineplot(data=milk_df, x="Date", y="Price_EUR_per_kg", hue="Country")
plt.title("Whole Milk Prices by Country")
plt.ylabel("EUR/kg")
plt.xlabel("Date")
plt.legend(title="Country")
plt.tight_layout()
plt.show()

# %%
milk_df = df[df["Product"] == "Skim Milk"]

plt.figure(figsize=(12, 5))
sns.lineplot(data=milk_df, x="Date", y="Price_EUR_per_kg", hue="Country")
plt.title("Skim Milk Prices by Country")
plt.ylabel("EUR/kg")
plt.xlabel("Date")
plt.legend(title="Country")
plt.tight_layout()
plt.show()

# %%
milk_df = df[df["Product"] == "Cheese"]

plt.figure(figsize=(12, 5))
sns.lineplot(data=milk_df, x="Date", y="Price_EUR_per_kg", hue="Country")
plt.title("Cheese Prices by Country")
plt.ylabel("EUR/kg")
plt.xlabel("Date")
plt.legend(title="Country")
plt.tight_layout()
plt.show()

# %%
milk_df = df[df["Product"] == "Butter"]

plt.figure(figsize=(12, 5))
sns.lineplot(data=milk_df, x="Date", y="Price_EUR_per_kg", hue="Country")
plt.title("Butter Prices by Country")
plt.ylabel("EUR/kg")
plt.xlabel("Date")
plt.legend(title="Country")
plt.tight_layout()
plt.show()
